# %% [markdown]
# ## Static vs Dynamic Typing:

# %% [markdown]
# : Dynamic Typing (Python): Types change during execution.
# : Static Typing: Fixed types before runtime.

# %% [markdown]
# ## Static vs Dynamic Binding:

# %% [markdown]
# : Static Binding: Types fixed at compile-time.
# : Dynamic Binding: Types associated at runtime, changeable during execution.

# %% [markdown]
# ## Stylish Declaration Techniques:

# %% [markdown]
# : Clear, efficient variable/structure declarations in Python.
# : Use Python's flexibility for concise, readable code.

# %%
## IN PYTHON THERE IS NO USE OF EARLY VARIABLE DECLARATION . WE CAN USE VARIABLE WHEN WE WANT IT ..

# %%
name = 'Piyush'

# %%
print(name)
# Out:
# Piyush

# %%
## IN PYTHON WE PERFORM DYNAMIC TYPING, AS WE KNOW WE DON'T HAVE TO WRITE THE DATA TYPE WHILE EXECUTING OR WRITING A CODE IN PYTHON.
## THIS IS DUE TO DYNAMIC TYPING...
## THEREFORE, PYTHON HAS DYNAMIC TYPING, AND STATIC TYPING IS THE OPPOSITE OF THIS.

# %%
name='Sneha'

# %%
print(name)
# Out:
# Sneha

# %%
## DYNAMIC BINDING REFERS TO ASSIGNING MULTIPLE VALUES IN ONE VARIABLE , IT CAN BE CHANGEABLE DURING RUNTIME OR EXECUTION.

# %%
name = 'Hello World'
print(name)
# Out:
# Hello World

# %% [markdown]
# ###### Dynamic Typing (PHP)
# $a = 5;
# ##### Static Typing (Java)
# int a = 5;

# %%
# Dynamic Binding Example
a = 5          # Assigning integer
print(a)
a = 'nitish'   # Reassigning string
print(a)
# Out:
# 5
# nitish

# %% [markdown]
# ###### Static Binding Example
# int a=23
# print(a)

# %% [markdown]
# ##### Special Syntax

# %%
a = 5; b = 6; c = 7

print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a, b, c = 4,7,10

print(a)
print(b)
print(c)
# Out:
# 4
# 7
# 10

# %%
a = b = c = 23
print(a, b, c) 
## WE CAN ALSO WRITE IT AS FOR MY CONVENIENCE.
a = b = c = 23
print(a,end=" ")
print(b,end=" ")
print(c)
# Out:
# 23 23 23
# 23 23 23

# %% [markdown]
# # KEYWORDS

# %% [markdown]
# ## Python Is a Case Sensitive Language

# %% [markdown]
# Keywords: reserved words, special meanings
# Cannot use as variable names

# %%
# Python has 33 keywords.
import keyword ## FOR CHECKING THE KEYWORDS THIS IS THE CODE WE HAVE TO EXECUTE. 
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Identifiers

# %% [markdown]
# : IDENTIFIERS are name for var, func, class, module, etc

# %% [markdown]
# Rules For Identifiers:
#
# Start with letter or _
# Followed by letters, digits, _
# Not a Python keyword

# %%
name = 'Piyush'
print(name)
# Out:
# Piyush

# %%
first_name = 'Sneha'
print(first_name)
# Out:
# Sneha

# %%
False = 'Ritesh'
print(False)
# Out:
#   Cell In[35], line 1
#     False = 'Ritesh'
#     ^
# SyntaxError: cannot assign to False
